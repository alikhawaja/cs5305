# %%
mport requests

url = "https://health.data.ny.gov/api/views/jxy9-yhdk/rows.csv"
r = requests.get(url)

with open("/opt/data/spark/myfile.csv", "wb") as f:
    f.write(r.content)

df = spark.read.csv("/tmp/myfile.csv", header=True, inferSchema=True)
df.show()
